# %% [markdown]
# # 作業1：
# 請寫一個函式用來計算 Mean Square Error
#
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt


def mean_absolute_error(y, yp):
    '''
    Calculate MAE
    Args:
        - y: actual value
        - yp: predicted value
    Return:
        - mae: MAE
    '''
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae


def mean_squared_error(y, yp):
    '''
    Calculate MSE
    Args:
        - y: actual value
        - yp: predicted value
    Return:
        - mse: MSE
    '''
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title('Assume we have data points')
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title('Assume we have data points (And the prediction)')
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print('The Mean squared error is %.3f' % (MSE))
print('The Mean absolute error is %.3f' % (MAE))
# Out:
# The Mean squared error is 213.171
# The Mean absolute error is 12.258

# %% [markdown]
# # 作業2：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

# %% [markdown]
# 1.你選的這組資料為何重要
# > [Titanic: Machine Learning from Disaster](https://www.kaggle.com/c/titanic/overview/evaluation)
# > 鐵達尼號生存預測，透過乘客資訊預估是否會在鐵達尼號意外下存活，資料集已事先整理過，為經典機器學習題目

# %% [markdown]
# 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# > 鐵達尼號歷史事件乘客資料集

# %% [markdown]
# 3.蒐集而來的資料型態為何
# > csv檔案，包括乘客資訊、親屬、票價、票號等資訊

# %% [markdown]
# 4.這組資料想解決的問題如何評估
# > 透過模型預測準確度(accuracy)來評估

# %% [markdown]
# # 作業3：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

# %% [markdown]
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# > 假設：車隊載客主要來源為巡迴攬客，每台車一天載客時數為8小時，利潤與載客行駛距離成正比
# > 目標(提升業績)：提升車隊平均每台車每小時載客行駛距離5% (KPI = 載客行駛距離(km)/ 單位時間(hr))

# %% [markdown]
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# > 透過公司營運報表可得知每台車一天載客距離、每台車一天收入金額

# %% [markdown]
# 3. 蒐集而來的資料型態為何
# > 載客距離與收入金額皆為數值型態

# %% [markdown]
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# > 透過載客距離與收入資料建立簡單線性迴歸模型，並以MSE、R-Squared指標驗證利潤與載客行駛距離模型擬合程度
